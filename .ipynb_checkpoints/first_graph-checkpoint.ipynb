# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_dallas_data.csv")

df["overall_score"] = pd.to_numeric(df["overall_score"], errors="coerce")

df["perc_ed"] = (
    df["perc_ed"]
    .str.replace("%", "", regex=False)
    .astype(float)
)

df["overall_score"] = df["overall_score"].replace({" ": None, ".": None})
df["overall_score"] = pd.to_numeric(df["overall_score"], errors="coerce")

df = df.dropna(subset=["perc_ed", "overall_score"])
fig, ax = plt.subplots()

sns.regplot(
    data=df,
    x="perc_ed",
    y="overall_score",
    ci=95,
    scatter_kws={"s": 80, "color": "steelblue", "edgecolors": "white"},
    line_kws={"color": "gray", "linewidth": 1.5},
    ax=ax
)

plt.title("SES vs Academic Performance - Dallas County High Schools")
plt.show()

# %%
import pandas as pd

df = pd.read_csv("cleaned_dallas_data.csv")

# Check what the columns actually look like
print(df["perc_ed"].unique())
print(df["overall_score"].unique())
# Out:
# ['67.2%' '66.6%' '49.2%' '73.8%' '53.0%' '49.5%' '76.4%' '34.0%' '63.5%'
#  '45.4%' '82.2%' '96.2%' '81.5%' '89.3%' '70.1%' '90.9%' '86.3%' '90.1%'
#  '92.7%' '95.1%' '88.1%' '96.7%' '92.9%' '82.6%' '73.7%' '53.4%' '91.1%'
#  '87.0%' '73.3%' '51.1%' '92.2%' '77.3%' '95.7%' '73.1%' '28.5%' '70.8%'
#  '70.5%' '63.8%' '38.4%' '69.7%' '87.9%' '79.7%' '29.6%' '98.0%' '79.8%'
#  '83.1%' '73.0%' '64.4%' '84.8%' '71.6%' '65.5%' '100.0%' '74.0%' '72.4%'
#  '73.6%' '78.1%' '62.8%' '48.4%' '88.2%' '41.7%' '62.0%' '77.7%' '62.6%'
#  '68.2%' '58.4%' '0.2%' '86.2%' '79.3%' '84.5%' '85.4%' '81.8%' '74.4%'
#  '74.2%' '78.8%' '80.6%' '80.0%' '51.7%' '50.4%' '35.4%' '58.2%' '77.9%'
#  '16.4%' '8.9%' '9.2%']
# ['81' '79' '82' '        .' '87' '83' '94' '67' '98' '86' '77' '80' '73'
#  '74' '63' '66' '69' '62' '78' '70' '72' '95' '85' '93' '89' '97' '76'
#  '88' '90' '84' '75' '92']
